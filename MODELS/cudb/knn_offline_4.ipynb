# %%
from comet_ml import Experiment, OfflineExperiment
import pickle
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GroupShuffleSplit
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from skopt import BayesSearchCV
from skopt import callbacks
from skopt.callbacks import CheckpointSaver
import skopt


ALGORITHM = 'KNN'
DS = 'DS1'

# %%
for SEGMENTS_LENGTH in [4]:

    EXPERIMENT_ID = F'BayesSearch_{ALGORITHM}_{DS}_{SEGMENTS_LENGTH}s'

    data_dir = f'D:\\FINKI\\8_dps\\Project\\DATA\\MODELS_DATA\\{DS}'
    X_train = pd.read_csv(f'{data_dir}\\segments_{SEGMENTS_LENGTH}s_train.csv')
    X_test = pd.read_csv(f'{data_dir}\\segments_{SEGMENTS_LENGTH}s_test.csv')

    y_train = X_train.pop('episode')
    y_test = X_test.pop('episode')

    results = list()
    workflow_dict = dict()

    hyperparameters_optimizer = BayesSearchCV(
        KNeighborsClassifier(),
        {
            'n_neighbors': (2, 50),
            'weights': ['distance', 'uniform'],
            'p': (1,5),
            'metric': ['minkowski'],
            'n_jobs': [2],
        },
        n_iter=2,
        cv=2,
        verbose = 10,
        n_jobs = 2,
        n_points = 2,
        scoring = 'accuracy',
        random_state = 42
    )

    checkpoint_callback = skopt.callbacks.CheckpointSaver(f'D:\\FINKI\\8_dps\\Project\\MODELS\\skopt_checkpoints\\{EXPERIMENT_ID}.pkl')
    hyperparameters_optimizer.fit(X_train, y_train, callback = [checkpoint_callback])
    skopt.dump(hyperparameters_optimizer, f'saved_models\\{EXPERIMENT_ID}.pkl')


    y_pred = hyperparameters_optimizer.best_estimator_.predict(X_test)


    for i in range(len(hyperparameters_optimizer.cv_results_['params'])):
        exp = OfflineExperiment(
                api_key = 'A8Lg71j9LtIrsv0deBA0DVGcR',
                project_name = ALGORITHM,
                workspace = "8_dps",
                auto_output_logging = 'native',
                offline_directory = f'D:\\FINKI\\8_dps\\Project\\MODELS\\comet_ml_offline_experiments\\{EXPERIMENT_ID}'
            )
        exp.set_name(f'{EXPERIMENT_ID}_{i+1}')
        exp.add_tags([DS, SEGMENTS_LENGTH,])
        for k, v in hyperparameters_optimizer.cv_results_.items():
            if k == "params": exp.log_parameters(dict(v[i]))
            else: exp.log_metric(k, v[i])
        exp.end()
# Out:
# Fitting 2 folds for each of 2 candidates, totalling 4 fits
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   1 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=2)]: Done   2 out of   4 | elapsed:    5.4s remaining:    5.4s
# [Parallel(n_jobs=2)]: Done   4 out of   4 | elapsed:    8.9s remaining:    0.0s
# [Parallel(n_jobs=2)]: Done   4 out of   4 | elapsed:    8.9s finished
# COMET WARNING: api_key was given, but is ignored in OfflineExperiment(); remember to set when you upload
# COMET WARNING: Native output logging mode is not available, fallbacking on basic output logging
# COMET INFO: ----------------------------------
# COMET INFO: Comet.ml OfflineExperiment Summary
# COMET INFO: ----------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : [OfflineExperiment will get URL after upload]
# COMET INFO:   Metrics:
# COMET INFO:     mean_fit_time     : 0.11400866508483887
# COMET INFO:     mean_score_time   : 3.834318161010742
# COMET INFO:     mean_test_score   : 0.8738989337042188
# COMET INFO:     param_metric      : minkowski
# COMET INFO:     param_n_jobs      : 2
# COMET INFO:     param_n_neighbors : 47
# COMET INFO:     param_p           : 2
# COMET INFO:     param_weights     : uniform
# COMET INFO:     rank_test_score   : 2
# COMET INFO:     split0_test_score : 0.8725081131200741
# COMET INFO:     split1_test_score : 0.8752897542883634
# COMET INFO:     std_fit_time      : 0.005000591278076172
# COMET INFO:     std_score_time    : 0.02100205421447754
# COMET INFO:     std_test_score    : 0.0013908205841446364
# COMET INFO:   Others:
# COMET INFO:     Name               : BayesSearch_KNN_DS1_4s_1
# COMET INFO:     offline_experiment : True
# COMET INFO:   Parameters:
# COMET INFO:     metric      : minkowski
# COMET INFO:     n_jobs      : 2
# COMET INFO:     n_neighbors : 47
# COMET INFO:     p           : 2
# COMET INFO:     weights     : uniform
# COMET INFO:   Uploads:
# COMET INFO:     environment details      : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# COMET INFO:     git-patch (uncompressed) : 1 (16 MB)
# COMET INFO:     installed packages       : 1
# COMET INFO:     notebook                 : 1
# COMET INFO:     source_code              : 1
# COMET INFO: ----------------------------------
# COMET INFO: Saving offline stats to disk before program termination (may take several seconds)
# COMET INFO: Starting saving the offline archive
# COMET INFO: To upload this offline experiment, run:
#     comet upload D:\FINKI\8_dps\Project\MODELS\comet_ml_offline_experiments\BayesSearch_KNN_DS1_4s\d2393742bd084267853324d06454d587.zip
# COMET WARNING: Native output logging mode is not available, fallbacking on basic output logging
# COMET INFO: ----------------------------------
# COMET INFO: Comet.ml OfflineExperiment Summary
# COMET INFO: ----------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : [OfflineExperiment will get URL after upload]
# COMET INFO:   Metrics:
# COMET INFO:     mean_fit_time     : 0.1220088005065918
# COMET INFO:     mean_score_time   : 3.3206006288528442
# COMET INFO:     mean_test_score   : 0.8793849482305671
# COMET INFO:     param_metric      : minkowski
# COMET INFO:     param_n_jobs      : 2
# COMET INFO:     param_n_neighbors : 37
# COMET INFO:     param_p           : 2
# COMET INFO:     param_weights     : uniform
# COMET INFO:     rank_test_score   : 1
# COMET INFO:     split0_test_score : 0.8800803585226394
# COMET INFO:     split1_test_score : 0.8786895379384948
# COMET INFO:     std_fit_time      : 0.004999399185180664
# COMET INFO:     std_score_time    : 0.01699388027191162
# COMET INFO:     std_test_score    : 0.0006954102920723182
# COMET INFO:   Others:
# COMET INFO:     Name               : BayesSearch_KNN_DS1_4s_2
# COMET INFO:     offline_experiment : True
# COMET INFO:   Parameters:
# COMET INFO:     metric      : minkowski
# COMET INFO:     n_jobs      : 2
# COMET INFO:     n_neighbors : 37
# COMET INFO:     p           : 2
# COMET INFO:     weights     : uniform
# COMET INFO:   Uploads:
# COMET INFO:     environment details      : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# COMET INFO:     git-patch (uncompressed) : 1 (16 MB)
# COMET INFO:     installed packages       : 1
# COMET INFO:     notebook                 : 1
# COMET INFO:     source_code              : 1
# COMET INFO: ----------------------------------
# COMET INFO: Starting saving the offline archive
# COMET INFO: To upload this offline experiment, run:
#     comet upload D:\FINKI\8_dps\Project\MODELS\comet_ml_offline_experiments\BayesSearch_KNN_DS1_4s\f9c9acd6abe04368b099fff74f6e40e9.zip
